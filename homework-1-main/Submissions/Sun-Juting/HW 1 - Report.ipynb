# %% [markdown]
# # Homework 1 Report
# **Student Name:** Sun Ju-ting.
#
# *UNI:* [js6881]
#
# ## Table of Contents
# 1. [Introduction](#intro)
# 2. [Project Description](#desc)
# 3. [Visulizations](#viz)
# 4. [Reflection](#reflect)
#
# <a id="intro"></a>
# ## 1. Introduction
# In this report, I will explore an interesting open-source project hosted on GitHub.
#
# <a id="desc"></a>
# ## 2. Project Description
# The project I chose to analyze is **yfinance**, which is a popular open-source tool that allows users to download market data from Yahoo! Finance directly into Python.
#
# * **Project Link:** [yfinance on Github](https://github.com/ranaroussi/yfinance)
#
# Here are three key features of this project:
# * It offers a simple, Pythonic way to download historical stock market data.
# * It can handle multi-level column data for advanced analytics.
# * It automatically fixes data errors and respects Yahoo's rate limits.
#
#
# <a id="viz"></a>
# ## 3. Visualizations
# (I will add content here later)
#
# <a id="reflection"></a>
# ## 4. Reflection
# (I will add content here later)
