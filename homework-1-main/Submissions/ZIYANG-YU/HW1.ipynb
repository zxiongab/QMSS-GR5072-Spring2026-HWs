# %% [markdown]
# ## Table of Contents
#
# - [1. Project Overview](#bullet1)
# - [2. Why this project is interesting](#bullet2)
# - [3. What this repository contains](#bullet3)
# - [4. Example from the project](#bullet4)
# - [5. Notes on commits: why notebook code looks “weird”](#bullet5)
# - [6. Reflection / Wrap-up](#bullet6)

# %% [markdown]
# # Exploring a Popular GitHub Project: HowToCook
# <a class="anchor" id="bullet1"></a>

# %% [markdown]
# ## Project1 Overview
# <a class="anchor" id="bullet1"></a>
#
#
# The project I chose is **HowToCook**, a very popular Chinese-language GitHub repository.
#
# GitHub project linhttps://github.com/Anduin2017/HowToCook?tab=readme-ov-fileToCook
#
# This repository collects a large number of Chinese home-style recipes and presents them in a clear, structured way. It has gained significant attention on GitHub and is widely shared among Chinese-speaking users.

# %% [markdown]
# ### Why this project is interesting
# <a class="anchor" id="bullet2"></a>
#
# I find this project interesting because it shows that GitHub is not only used for *software engineering*, but also for sharing **everyday knowledge**.
#
# The project demonstrates how open-source platforms can be used creatively beyond traditional programming tasks.

# %% [markdown]
# <a class="anchor" id="bullet3"></a>
# ## What this repository contains
# >
#
# This repository includes:
# - Step-by-step Chinese cooking instructions
# - Images illustrating finished dishes
# - Contributions from many GitHub users
# - Clear organization using Markdown files

# %% [markdown]
# <a class="anchor" id="bullet4"></a>
# ## Example from the project
# >
#
# Below is an example image illustrating a dish from the type of content found in this repository.

# %% [markdown]
# ![](4.jpeg)

# %% [markdown]
# <a class="anchor" id="bullet5"></a>
# ## Notes on commits: why notebook code looks “weird”
#
# When I checked the commit history of my Jupyter Notebook, the code looked unfamiliar and hard to read.
# I think tThis is because a notebook file does not only save Python code, but also saves cell structure
# and other information.
#
# However, the Python script file I created looks much clearer in the commit history,
# because it only contains normal Python code.

# %% [markdown]
# ## Reflection on commit history
# <a class="anchor" id="bullet6"></a>
#
# When I looked at the commit history for my Jupyter Notebook, the code looked unfamiliar because Jupyter Notebook files store outputs, metadata, and cell structure in a JSON format. This makes the commit history harder to read.
#
# In contrast, the Python script I created contained plain text Python code, which looked familiar and easy to understand when viewing the commit history.
# cipes.
