# %%
print("first commit")

# %%
print("second commit")

# %%
print("third commit")

# %% [markdown]
# # HW1-Modern Data Structure

# %% [markdown]
# ## I-Yuan Chen

# %% [markdown]
# ## UNI: ic2704

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# * [1. Project Description](#bullet1)
# * [2. Project Visualization](#bullet2)
# * [3. Reflection](#bullet3)

# %% [markdown]
# ## 1. Project Description

# %% [markdown]
# The project I select is "PyGWalker (short for Python Graphic Walker)". Which is a Python library that turns a pandas DataFrame into an interactive visual analytics interface, letting users explore and visualize data with a drag-and-drop UI, similar to tools like Tableau but all inside Jupyter Notebooks. It makes creating plots easier and more intuitive.

# %% [markdown]
# ***Project link:*** [click me](https://github.com/Kanaries/pygwalker?utm_source=chatgpt.com)

# %% [markdown]
# ***Key features***

# %% [markdown]
# - PyGWalker lets users create charts by dragging and dropping variables instead of writing plotting code.

# %% [markdown]
# - It works directly with pandas DataFrames, so you can visualize your data instantly with one line of Python.

# %% [markdown]
# - It provides an interactive, Tableau-style dashboard inside Jupyter Notebook for filtering, grouping, and exploring data.

# %% [markdown]
# ## 2. Project Visualization

# %% [markdown]
# Below is the screenshot of the project.

# %% [markdown]
# ![image1.png](attachment:e1c9e9c8-0fcf-4bb8-865e-29441642fff6.png)

# %% [markdown]
# This screenshot shows the GitHub README page of Kanaries’s PyGWalker project, featuring a large banner with the slogan Turn your data into an interactive UI for exploratory data analysis and a preview of the interactive visualization dashboard inside a Jupyter Notebook. The right sidebar displays project details such as contributors, deployments, and programming languages used, highlighting that the tool is mainly built with Python and Jupyter Notebook.

# %% [markdown]
# ## 3. Reflection

# %% [markdown]
# **When you looked at your commit history on either GitHub or GitHub Desktop for the Jupyter Notebook, did the code look familiar? What about the code for the python script you made? Why did the code for Jupyter Notebook seem foreign? Please include your answer at the end of your Jupyter Notebook file.**

# %% [markdown]
# When I checked the commit history, the Python script looked familiar because it only showed the exact lines of code I wrote. However, the Jupyter Notebook looked strange and messy with many extra symbols and unfamiliar text. This is because a .ipynb file is stored in JSON format and includes metadata, outputs, and notebook settings in addition to the code. Therefore, the notebook history looked foreign, while the .py script was clean and easy to understand.
