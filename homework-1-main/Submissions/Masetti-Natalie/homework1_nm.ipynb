# %% [markdown]
# # Pyktok Homework Report
# ## Natalie Masetti

# %% [markdown]
# I will be looking at [this GitHub page](https://github.com/dfreelon/pyktok), which allows a user to collect data from **TikTok**.

# %% [markdown]
# * [1. Pyktok Functionality](#section1)
# * [2. Pyktok Review](#section2)
# * [3. Plot](#section3)
# * [4. Conclusion](#section4)

# %% [markdown]
# # Pyktok Functionality <a class="anchor" id="section1"></a>
#
# *List of Pyktok Functions:*
# - Download data from TikTok, including videos, metadata, and comments
# - Download things like hashtag, user, and "You May Like" data
# - Download JSON files from TikTok

# %% [markdown]
# # Pyktok Review <a class="anchor" id="section2"></a>
#
# I've been wanting to work on a project that examines how movie reviews have changed since the rise of short-form video, especially TikTok. To that end, I needed to figure out how to scrape TikTok for certain hashtags and language. This repository on GitHub provides a simple way to get metadata from TikTok, including hashtag data, which will be useful for my project. The code is simple, which will be useful for a novice Python user such as myself.

# %% [markdown]
# # Pyktok Plot <a class="anchor" id="section3"></a>
# (*There weren't any plots in this repository, so I'm uploading a screenshot of the code I think I'd use*)
# ![code_pic.png](attachment:7e51e68f-e354-40b8-8d9f-e32149f44f22.png)

# %% [markdown]
# # Pyktok Conclusion <a class="anchor" id="section4"></a>
#
# In sum, I think this repo will be useful for getting a sense of the code I should be using for my TikTok-movie review project. However, this is only one method I could potentially use - I will still look into other GitHub repos to see if anyone has anything that is more in line with my project's requirements.

# %% [markdown]
# ## Commit History Report
#
# When I looked at the commit history for the Jupyter notebook, some of the code was familiar and some was not. For example, I see new additions to the Jupyter notebook that were not there before, including metadata, id, and source variables above each chunk of text, double @ signs, and brackets and parantheses. The python script looked very familiar - the only new addition was the @ symbols. Both show what has been added and subtracted from previous versions of the files. I think the code for the Jupyter notebook looks different because of the type of file it is - it is Markdown, so it probably needs some different html/JSON script to help it run.
