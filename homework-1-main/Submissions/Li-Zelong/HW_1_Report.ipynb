# %% [markdown]
# # Homework 1 Report | Li Zelong | zl3652
#
# # Project :*UNet- Instance Segmentation*
# ### Project GitHub: https://github.com/zhixuhao/unet
#
# ## Table of Contents
# 1. [Project Overview](#bullet1)
# 2. [What It Does](#bullet2)
# 3. [Key Features](#bullet3)
# 4. [Reflection on Commit History](#bullet4)

# %% [markdown]
# ## 1. Project Overview <a class="anchor" id="bullet1"></a>
#
# This report highlights the *Pytorch-UNet* project, an open-source implementation of the U-Net architecture for biomedical image segmentation.
#
# ### Background
# U-Net is widely used to separate **objects of interest** from medical images by learning pixel-wise masks.

# %% [markdown]
# ## 2. What It Does <a class="anchor" id="bullet2"></a>
#
# Given an input image, the model predicts a segmentation mask. This is useful for tasks like identifying tumors, cells, or anatomical structures.
#
# **Input image**
#
# ![input image](https://raw.githubusercontent.com/zhixuhao/unet/master/img/0test.png)
#
# **Predicted mask**
#
# ![predicted mask](https://raw.githubusercontent.com/zhixuhao/unet/master/img/0label.png)

# %% [markdown]
# ## 3. Key Features <a class="anchor" id="bullet3"></a>
#
# - Supports **GPU training** with PyTorch
# - Includes data augmentation **utilities**
# - **Provides scripts** for training and prediction
# - **Easy** to adapt for new datasets
