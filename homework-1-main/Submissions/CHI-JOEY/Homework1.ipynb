# %% [markdown]
# # **Homework 1**

# %% [markdown]
# ## Table of Contents
# 1. [Github Project Link](#bullet1)
# 2. [Plot](#bullet2)
# 3. [Project Overview](#bullet3)

# %% [markdown]
# ## **Project Link** <a class="anchor" id="bullet1"></a>
# https://github.com/SphericalSilver/NYC-Schools-Survey-Data?tab=readme-ov-file
#
# ## **Project Title**: "Exploring Survey Data on NYC Schools"

# %% [markdown]
# ## **Plot <a class="anchor" id="bullet2"></a>**
#
# ### *Plot 1: Box Plot visulizations of differences in perceptions between parents, student, and teacher*
# ![BoxPlot.png](attachment:ea1122c2-bb35-4d03-a391-29992b3421af.png)
#
# ### *Plot 2: A correlation matrix between the average SAT score and other variables*
# ![Correlation.png](attachment:e3bb04c3-2b36-4315-81f7-1d7e2a43ef69.png)

# %% [markdown]
# ## **Project Overview <a class="anchor" id="bullet3"></a>**
#
# ### Research Question
# This project is analyzing survey data to investigate whether the perceptions of schools by
# 1) Students,
# 2) Teachers, and
# 3) Parents
#
# appeared correlated to the academic success of students from that school (the metric for academic success being SAT scores).
#
#
# ### Factors that have been analyzed
# - Safety
# - Engagement
# - Communication
# - Academics
