# %% [markdown]
# Table of Content
#
# * [1. Github Link](#bullet1)
# * [2. Plot](#bullet2)

# %% [markdown]
# # **1. Github Link** <a class="anchor" id="bullet1"></a>
# ***The Github repo I'm describing:***
# https://github.com/zxiongab/Group_3/tree/main

# %% [markdown]
# # **2. Plot** <a class="anchor" id="bullet2"></a>

# %% [markdown]
# ## *Plot of metrics for train model and validation model*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## *List of metrics of another test model (InceptionV3)*

# %% [markdown]
# - Test Accuracy: 0.9060
# - Test Precision: 0.9074
# - Test Recall: 0.9035
# - Test F1-Score: 0.9054
