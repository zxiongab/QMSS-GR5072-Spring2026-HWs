# %% [markdown]
# # Github Project Report

# %% [markdown]
# Suiyi Chen
# sc5737

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# - 1. [Project link](#bullet1)
# - 2. [Project overview](#bullet2)
# - 3. [Project screenshot](#bullet3)

# %% [markdown]
# ## 1. Project link <a class="anchor" id="bullet1"></a>

# %% [markdown]
# link: https://github.com/Lissy93/web-check

# %% [markdown]
# ## 2. Project overview <a class="anchor" id="bullet2"></a>

# %% [markdown]
# This project, **Web-Check**, provides comprehensive website analysis. It can examine：
# - *IP information*
# - *SSL chains*
# - *DNS records*
# - *cookies*
# - *headers*
# - *domain details*
# - *search crawl rules*
# - *page maps*
# - *server locations*
# - *redirect logs*
# - *open ports*
# - *traceroutes*
# - *DNS security extensions*
# - *site performance*
# - *trackers*
# - *associated hostnames*
# - and even the *carbon footprint* of a website

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Metric': ['Stars', 'Watching', 'Forks'],
    'Count': [31500, 165, 2500]
}

df = pd.DataFrame(data)

ax = df.plot.bar(
    x='Metric',
    y='Count',
    color=['gold','skyblue','lightgreen'],
    legend=False,
    figsize=(6,4),
    ylabel='Count',
    title='web-check.xyz GitHub Stats'
)
ax.bar_label(ax.containers[0], fmt='%d', padding=3)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 3. Project screenchot <a class="anchor" id="bullet3"></a>

# %% [markdown]
# ![](https://raw.githubusercontent.com/Lissy93/web-check/HEAD/.github/screenshots/web-check-screenshot3.png)

# %% [markdown]
# Ref: https://raw.githubusercontent.com/Lissy93/web-check/HEAD/.github/screenshots/web-check-screenshot3.png

# %% [markdown]
# ## Question 6
# - The Jupyter Notebook code looked foreign in the commit history because `.ipynb` files are stored as JSON, not Python. GitHub shows the JSON format, so it looks different from the code inside Jupyter.
# - The Python script code looked familiar because `.py` files are plain text. GitHub shows exactly what I wrote.
