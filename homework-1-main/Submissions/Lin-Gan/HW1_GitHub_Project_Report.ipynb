# %% [markdown]
# # Homework 1 Report: A GitHub Project I Find Interesting
#
# **Project link:** https://github.com/s0md3v/roop
#
# This notebook is a short report describing a GitHub project and practicing Markdown + Git workflow.

# %% [markdown]
# # Table of Contents
#
# 1. [Project Overview](#bullet1)
# 2. [What the project does](#bullet2)
#    - [Ethics & responsible use](#bullet2_1)
# 3. [A simple plot](#bullet3)
# 4. [Key takeaways](#bullet4)
# 5. [Commit history reflection](#bullet5)

# %% [markdown]
# # 1. Project Overview <a class="anchor" id="bullet1"></a>
#
# The repository I chose is **roop**, a project hosted on GitHub.
# At a high level, it is a tool related to *face swapping* workflows.
# This repo is widely known and has attracted a lot of attention from the GitHub community.

# %% [markdown]
# # 2. What the project does <a class="anchor" id="bullet2"></a>
#
# In simple terms, this project focuses on automating face swap outputs using a streamlined workflow.
# It is an example of how open-source projects can make complex computer-vision tasks easier to run.
#
# ## 2.1 Ethics & responsible use <a class="anchor" id="bullet2_1"></a>
#
# This type of technology can be misused, so responsible use matters. For example:
# - Always get **consent** from the people involved.
# - Clearly label edited or synthetic media when sharing.
# - Follow platform rules and local laws.

# %%
import matplotlib.pyplot as plt

# Simple GitHub metrics (approximate values)
metrics = {"Stars (k)": 30.5, "Forks (k)": 6.9, "Watchers": 268}

plt.bar(metrics.keys(), metrics.values())
plt.title("GitHub metrics for s0md3v/roop")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 3. A simple plot <a class="anchor" id="bullet3"></a>
#
# The plot above shows basic GitHub engagement metrics.
# A high number of stars and forks suggests that many people found the project interesting or useful.

# %% [markdown]
# # 4. Key takeaways <a class="anchor" id="bullet4"></a>
#
# Main points I learned from this repo:
# - Open-source projects can make complex workflows easier to access.
# - Community interest can be seen through stars/forks.
# - Tools like this require *responsible* and **ethical** use.

# %% [markdown]
# # 5. Commit history reflection <a class="anchor" id="bullet5"></a>
#
# When I looked at commit history, the code changes in the `.py` script looked familiar because it is plain text.
# However, changes in a Jupyter Notebook (`.ipynb`) can look foreign because notebooks are saved as **JSON** files.
# They include extra metadata (outputs, execution counts, cell structure), so the diff is more cluttered than a normal script.
